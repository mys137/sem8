# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import PIL
from PIL import Image
from skimage.color import rgb2gray
from scipy import ndimage as ndi
import cv2
import os
from os import listdir
from sklearn.utils import shuffle

import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from keras.optimizers import SGD
from keras import regularizers
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
directory_root = "../input/plantvillage/PlantVillage"
print(len(listdir(directory_root)))
# Out:
# 15

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
                
        for single_plant_disease_image in plant_disease_folder_list :
            if single_plant_disease_image == ".DS_Store" :
                plant_disease_folder_list.remove(single_plant_disease_image)

        for image in plant_disease_folder_list:
            image_directory = f"{directory_root}/{plant_folder}/{image}"
            if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                image_list.append(image_directory)
                label_list.append(plant_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Image loading completed

# %%
img_info = pd.DataFrame({'image_path':image_list,'label':label_list})
print(img_info.head())
print(len(img_info))
# Out:
#                                           image_path                      label
# 0  ../input/plantvillage/PlantVillage/Tomato_Sept...  Tomato_Septoria_leaf_spot
# 1  ../input/plantvillage/PlantVillage/Tomato_Sept...  Tomato_Septoria_leaf_spot
# 2  ../input/plantvillage/PlantVillage/Tomato_Sept...  Tomato_Septoria_leaf_spot
# 3  ../input/plantvillage/PlantVillage/Tomato_Sept...  Tomato_Septoria_leaf_spot
# 4  ../input/plantvillage/PlantVillage/Tomato_Sept...  Tomato_Septoria_leaf_spot
# 20636

# %%
#new column (empty)
img_info["labels_integer"] = None
#index of new column
index_labels_integer = img_info.columns.get_loc("labels_integer")
#index of species column
index_species = img_info.columns.get_loc("label")
#to assign numeric labels starting with 0 for the first species
k = 0 
for i in range(len(img_info)):
    if i == 0:
        img_info.iloc[i, index_labels_integer] = k #here, k == 0
    if i > 0:
        if img_info.iloc[i-1, index_species] == img_info.iloc[i, index_species]:
            img_info.iloc[i, index_labels_integer] = k
        else:
            k += 1
            img_info.iloc[i, index_labels_integer] = k
img_info.tail()
# Out:
#                                               image_path      ...       labels_integer
# 20631  ../input/plantvillage/PlantVillage/Pepper__bel...      ...                   14
# 20632  ../input/plantvillage/PlantVillage/Pepper__bel...      ...                   14
# 20633  ../input/plantvillage/PlantVillage/Pepper__bel...      ...                   14
# 20634  ../input/plantvillage/PlantVillage/Pepper__bel...      ...                   14
# 20635  ../input/plantvillage/PlantVillage/Pepper__bel...      ...                   14
#
# [5 rows x 3 columns]

# %%
img_info = shuffle(img_info)
list_vectors = []

for image_path in img_info.image_path:
    #read as rgb array
    img = Image.open(image_path)
    size = (64, 64)
    img = img.resize(size, PIL.Image.ANTIALIAS)  
    img_array = np.array(img)
    #append image vector to list
    list_vectors.append(img_array)
    
print(len(list_vectors))
# Out:
# 20636

# %%
X = np.stack((list_vectors))
Y =  img_info['labels_integer']
print(X.shape)
# Out:
# (20636, 64, 64, 3)

# %%
X = X/255
Y_one_hot = keras.utils.to_categorical(Y, num_classes=15)
print(Y.shape, Y_one_hot.shape)
# Out:
# (20636,) (20636, 15)

# %%
np.savez("x_images_arrayscnn", X)
np.savez("y_numeric_labelscnn", Y_one_hot)

# %%
x_npz = np.load("x_images_arrayscnn.npz")
X = x_npz['arr_0']

y_npz = np.load("y_numeric_labelscnn.npz")
Y_one_hot = y_npz['arr_0']

print(X.shape)
# Out:
# (20636, 64, 64, 3)

# %%
split_train = 0.8 #train 0.8, validate 0.1, test 0.1
split_val = 0.9
index_train = int(split_train*len(X))
index_val = int(split_val*len(X))

X_train = X[:index_train]
X_val = X[index_train:index_val]
X_test = X[index_val:]

Y_train = Y_one_hot[:index_train]
Y_val = Y_one_hot[index_train:index_val]
Y_test = Y_one_hot[index_val:]


print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (16508, 64, 64, 3) (2064, 64, 64, 3) (2064, 64, 64, 3) (16508, 15) (2064, 15) (2064, 15)

# %%
input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3]) 
num_classes = 15

model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(64, (5, 5)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.7))
model.add(Flatten())
model.add(Dense(1000))
model.add(Activation('relu'))
model.add(Dropout(0.7))
model.add(Dense(num_classes, activation='softmax'))


model.compile(optimizer=keras.optimizers.Adam(lr=0.0003, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-8, amsgrad=False),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 60, 60, 32)        2432
# _________________________________________________________________
# activation_1 (Activation)    (None, 60, 60, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 64)        51264
# _________________________________________________________________
# activation_2 (Activation)    (None, 26, 26, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 13, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10816)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              10817000
# _________________________________________________________________
# activation_3 (Activation)    (None, 1000)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                15015
# =================================================================
# Total params: 10,885,711
# Trainable params: 10,885,711
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model_file = "disease_selected_100.h5"
best_model = ModelCheckpoint(best_model_file, monitor='val_loss', verbose=1, save_best_only=True)

print('Training model...')
results = model.fit(X_train, Y_train, epochs=200, batch_size=64, validation_data=(X_val, Y_val), callbacks=[best_model])
print('Traing finished.')

print('Loading the best model...')
model = load_model(best_model_file)
print('Best Model loaded!')
# Out:
# Training model...
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 16508 samples, validate on 2064 samples
# Epoch 1/200
# 16508/16508 [==============================] - 7s 396us/step - loss: 1.7983 - acc: 0.4310 - val_loss: 1.0201 - val_acc: 0.6793
#
# Epoch 00001: val_loss improved from inf to 1.02015, saving model to disease_selected_100.h5
# Epoch 2/200
# 16508/16508 [==============================] - 4s 216us/step - loss: 1.0705 - acc: 0.6525 - val_loss: 0.7900 - val_acc: 0.7369
#
# Epoch 00002: val_loss improved from 1.02015 to 0.78999, saving model to disease_selected_100.h5
# Epoch 3/200
# 16508/16508 [==============================] - 4s 223us/step - loss: 0.8448 - acc: 0.7206 - val_loss: 0.6155 - val_acc: 0.7965
#
# Epoch 00003: val_loss improved from 0.78999 to 0.61547, saving model to disease_selected_100.h5
# Epoch 4/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.7053 - acc: 0.7674 - val_loss: 0.4774 - val_acc: 0.8445
#
# Epoch 00004: val_loss improved from 0.61547 to 0.47738, saving model to disease_selected_100.h5
# Epoch 5/200
# 16508/16508 [==============================] - 4s 223us/step - loss: 0.6136 - acc: 0.7962 - val_loss: 0.4444 - val_acc: 0.8445
#
# Epoch 00005: val_loss improved from 0.47738 to 0.44442, saving model to disease_selected_100.h5
# Epoch 6/200
# 16508/16508 [==============================] - 4s 215us/step - loss: 0.5259 - acc: 0.8232 - val_loss: 0.3652 - val_acc: 0.8794
#
# Epoch 00006: val_loss improved from 0.44442 to 0.36524, saving model to disease_selected_100.h5
# Epoch 7/200
# 16508/16508 [==============================] - 4s 223us/step - loss: 0.4871 - acc: 0.8377 - val_loss: 0.3666 - val_acc: 0.8784
#
# Epoch 00007: val_loss did not improve from 0.36524
# Epoch 8/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.4414 - acc: 0.8516 - val_loss: 0.3210 - val_acc: 0.8847
#
# Epoch 00008: val_loss improved from 0.36524 to 0.32101, saving model to disease_selected_100.h5
# Epoch 9/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.4057 - acc: 0.8659 - val_loss: 0.3070 - val_acc: 0.8978
#
# Epoch 00009: val_loss improved from 0.32101 to 0.30700, saving model to disease_selected_100.h5
# Epoch 10/200
# 16508/16508 [==============================] - 4s 223us/step - loss: 0.3599 - acc: 0.8787 - val_loss: 0.2679 - val_acc: 0.9075
#
# Epoch 00010: val_loss improved from 0.30700 to 0.26793, saving model to disease_selected_100.h5
# Epoch 11/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.3446 - acc: 0.8835 - val_loss: 0.2500 - val_acc: 0.9138
#
# Epoch 00011: val_loss improved from 0.26793 to 0.24998, saving model to disease_selected_100.h5
# Epoch 12/200
# 16508/16508 [==============================] - 4s 220us/step - loss: 0.3201 - acc: 0.8916 - val_loss: 0.2336 - val_acc: 0.9234
#
# Epoch 00012: val_loss improved from 0.24998 to 0.23358, saving model to disease_selected_100.h5
# Epoch 13/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.2886 - acc: 0.9054 - val_loss: 0.2193 - val_acc: 0.9259
#
# Epoch 00013: val_loss improved from 0.23358 to 0.21926, saving model to disease_selected_100.h5
# Epoch 14/200
# 16508/16508 [==============================] - 4s 223us/step - loss: 0.2708 - acc: 0.9088 - val_loss: 0.2378 - val_acc: 0.9128
#
# Epoch 00014: val_loss did not improve from 0.21926
# Epoch 15/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.2614 - acc: 0.9100 - val_loss: 0.2055 - val_acc: 0.9327
#
# Epoch 00015: val_loss improved from 0.21926 to 0.20547, saving model to disease_selected_100.h5
# Epoch 16/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.2562 - acc: 0.9124 - val_loss: 0.2184 - val_acc: 0.9264
#
# Epoch 00016: val_loss did not improve from 0.20547
# Epoch 17/200
# 16508/16508 [==============================] - 4s 225us/step - loss: 0.2328 - acc: 0.9205 - val_loss: 0.2020 - val_acc: 0.9307
#
# Epoch 00017: val_loss improved from 0.20547 to 0.20202, saving model to disease_selected_100.h5
# Epoch 18/200
# 16508/16508 [==============================] - 4s 218us/step - loss: 0.2177 - acc: 0.9268 - val_loss: 0.1853 - val_acc: 0.9385
#
# Epoch 00018: val_loss improved from 0.20202 to 0.18533, saving model to disease_selected_100.h5
# Epoch 19/200
# 16508/16508 [==============================] - 4s 221us/step - loss: 0.2132 - acc: 0.9286 - val_loss: 0.1843 - val_acc: 0.9365
#
# Epoch 00019: val_loss improved from 0.18533 to 0.18431, saving model to disease_selected_100.h5
# Epoch 20/200
# 16508/16508 [==============================] - 4s 216us/step - loss: 0.2009 - acc: 0.9309 - val_loss: 0.1971 - val_acc: 0.9302
#
# Epoch 00020: val_loss did not improve from 0.18431
# Epoch 21/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.1819 - acc: 0.9355 - val_loss: 0.1661 - val_acc: 0.9448
#
# Epoch 00021: val_loss improved from 0.18431 to 0.16613, saving model to disease_selected_100.h5
# Epoch 22/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.1909 - acc: 0.9339 - val_loss: 0.1699 - val_acc: 0.9419
#
# Epoch 00022: val_loss did not improve from 0.16613
# Epoch 23/200
# 16508/16508 [==============================] - 4s 220us/step - loss: 0.1738 - acc: 0.9404 - val_loss: 0.1706 - val_acc: 0.9457
#
# Epoch 00023: val_loss did not improve from 0.16613
# Epoch 24/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.1650 - acc: 0.9455 - val_loss: 0.1678 - val_acc: 0.9414
#
# Epoch 00024: val_loss did not improve from 0.16613
# Epoch 25/200
# 16508/16508 [==============================] - 4s 216us/step - loss: 0.1644 - acc: 0.9435 - val_loss: 0.1821 - val_acc: 0.9404
#
# Epoch 00025: val_loss did not improve from 0.16613
# Epoch 26/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.1562 - acc: 0.9481 - val_loss: 0.2070 - val_acc: 0.9230
#
# Epoch 00026: val_loss did not improve from 0.16613
# Epoch 27/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.1519 - acc: 0.9491 - val_loss: 0.1483 - val_acc: 0.9486
#
# Epoch 00027: val_loss improved from 0.16613 to 0.14826, saving model to disease_selected_100.h5
# Epoch 28/200
# 16508/16508 [==============================] - 4s 212us/step - loss: 0.1367 - acc: 0.9527 - val_loss: 0.1544 - val_acc: 0.9516
#
# Epoch 00028: val_loss did not improve from 0.14826
# Epoch 29/200
# 16508/16508 [==============================] - 4s 220us/step - loss: 0.1345 - acc: 0.9532 - val_loss: 0.1641 - val_acc: 0.9457
#
# Epoch 00029: val_loss did not improve from 0.14826
# Epoch 30/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.1329 - acc: 0.9558 - val_loss: 0.1694 - val_acc: 0.9423
#
# Epoch 00030: val_loss did not improve from 0.14826
# Epoch 31/200
# 16508/16508 [==============================] - 4s 212us/step - loss: 0.1232 - acc: 0.9577 - val_loss: 0.1676 - val_acc: 0.9448
#
# Epoch 00031: val_loss did not improve from 0.14826
# Epoch 32/200
# 16508/16508 [==============================] - 3s 212us/step - loss: 0.1172 - acc: 0.9595 - val_loss: 0.1487 - val_acc: 0.9482
#
# Epoch 00032: val_loss did not improve from 0.14826
# Epoch 33/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.1245 - acc: 0.9573 - val_loss: 0.1585 - val_acc: 0.9486
#
# Epoch 00033: val_loss did not improve from 0.14826
# Epoch 34/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.1239 - acc: 0.9566 - val_loss: 0.1323 - val_acc: 0.9486
#
# Epoch 00034: val_loss improved from 0.14826 to 0.13228, saving model to disease_selected_100.h5
# Epoch 35/200
# 16508/16508 [==============================] - 4s 223us/step - loss: 0.1149 - acc: 0.9612 - val_loss: 0.1493 - val_acc: 0.9472
#
# Epoch 00035: val_loss did not improve from 0.13228
# Epoch 36/200
# 16508/16508 [==============================] - 4s 232us/step - loss: 0.1158 - acc: 0.9609 - val_loss: 0.1351 - val_acc: 0.9564
#
# Epoch 00036: val_loss did not improve from 0.13228
# Epoch 37/200
# 16508/16508 [==============================] - 4s 220us/step - loss: 0.1109 - acc: 0.9630 - val_loss: 0.1457 - val_acc: 0.9525
#
# Epoch 00037: val_loss did not improve from 0.13228
# Epoch 38/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.0961 - acc: 0.9697 - val_loss: 0.1392 - val_acc: 0.9530
#
# Epoch 00038: val_loss did not improve from 0.13228
# Epoch 39/200
# 16508/16508 [==============================] - 4s 218us/step - loss: 0.0978 - acc: 0.9663 - val_loss: 0.1455 - val_acc: 0.9486
#
# Epoch 00039: val_loss did not improve from 0.13228
# Epoch 40/200
# 16508/16508 [==============================] - 4s 218us/step - loss: 0.1050 - acc: 0.9629 - val_loss: 0.1364 - val_acc: 0.9578
#
# Epoch 00040: val_loss did not improve from 0.13228
# Epoch 41/200
# 16508/16508 [==============================] - 4s 216us/step - loss: 0.0993 - acc: 0.9646 - val_loss: 0.1299 - val_acc: 0.9603
#
# Epoch 00041: val_loss improved from 0.13228 to 0.12985, saving model to disease_selected_100.h5
# Epoch 42/200
# 16508/16508 [==============================] - 3s 212us/step - loss: 0.0851 - acc: 0.9711 - val_loss: 0.1511 - val_acc: 0.9491
#
# Epoch 00042: val_loss did not improve from 0.12985
# Epoch 43/200
# 16508/16508 [==============================] - 4s 220us/step - loss: 0.0931 - acc: 0.9677 - val_loss: 0.1660 - val_acc: 0.9438
#
# Epoch 00043: val_loss did not improve from 0.12985
# Epoch 44/200
# 16508/16508 [==============================] - 4s 212us/step - loss: 0.0864 - acc: 0.9715 - val_loss: 0.1491 - val_acc: 0.9535
#
# Epoch 00044: val_loss did not improve from 0.12985
# Epoch 45/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0891 - acc: 0.9704 - val_loss: 0.1416 - val_acc: 0.9496
#
# Epoch 00045: val_loss did not improve from 0.12985
# Epoch 46/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0786 - acc: 0.9723 - val_loss: 0.1411 - val_acc: 0.9530
#
# Epoch 00046: val_loss did not improve from 0.12985
# Epoch 47/200
# 16508/16508 [==============================] - 3s 212us/step - loss: 0.0884 - acc: 0.9707 - val_loss: 0.1934 - val_acc: 0.9390
#
# Epoch 00047: val_loss did not improve from 0.12985
# Epoch 48/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.0863 - acc: 0.9709 - val_loss: 0.1666 - val_acc: 0.9486
#
# Epoch 00048: val_loss did not improve from 0.12985
# Epoch 49/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0756 - acc: 0.9741 - val_loss: 0.1422 - val_acc: 0.9540
#
# Epoch 00049: val_loss did not improve from 0.12985
# Epoch 50/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0742 - acc: 0.9762 - val_loss: 0.1276 - val_acc: 0.9588
#
# Epoch 00050: val_loss improved from 0.12985 to 0.12764, saving model to disease_selected_100.h5
# Epoch 51/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0844 - acc: 0.9723 - val_loss: 0.1523 - val_acc: 0.9472
#
# Epoch 00051: val_loss did not improve from 0.12764
# Epoch 52/200
# 16508/16508 [==============================] - 4s 218us/step - loss: 0.0846 - acc: 0.9732 - val_loss: 0.1456 - val_acc: 0.9520
#
# Epoch 00052: val_loss did not improve from 0.12764
# Epoch 53/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0737 - acc: 0.9763 - val_loss: 0.1339 - val_acc: 0.9612
#
# Epoch 00053: val_loss did not improve from 0.12764
# Epoch 54/200
# 16508/16508 [==============================] - 3s 212us/step - loss: 0.0765 - acc: 0.9751 - val_loss: 0.1519 - val_acc: 0.9506
#
# Epoch 00054: val_loss did not improve from 0.12764
# Epoch 55/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0679 - acc: 0.9766 - val_loss: 0.1973 - val_acc: 0.9360
#
# Epoch 00055: val_loss did not improve from 0.12764
# Epoch 56/200
# 16508/16508 [==============================] - 4s 212us/step - loss: 0.0663 - acc: 0.9783 - val_loss: 0.1616 - val_acc: 0.9506
#
# Epoch 00056: val_loss did not improve from 0.12764
# Epoch 57/200
# 16508/16508 [==============================] - 4s 212us/step - loss: 0.0803 - acc: 0.9738 - val_loss: 0.1685 - val_acc: 0.9496
#
# Epoch 00057: val_loss did not improve from 0.12764
# Epoch 58/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0704 - acc: 0.9769 - val_loss: 0.1512 - val_acc: 0.9593
#
# Epoch 00058: val_loss did not improve from 0.12764
# Epoch 59/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.0664 - acc: 0.9770 - val_loss: 0.1161 - val_acc: 0.9617
#
# Epoch 00059: val_loss improved from 0.12764 to 0.11606, saving model to disease_selected_100.h5
# Epoch 60/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.0618 - acc: 0.9792 - val_loss: 0.1107 - val_acc: 0.9608
#
# Epoch 00060: val_loss improved from 0.11606 to 0.11073, saving model to disease_selected_100.h5
# Epoch 61/200
# 16508/16508 [==============================] - 4s 225us/step - loss: 0.0628 - acc: 0.9779 - val_loss: 0.1179 - val_acc: 0.9622
#
# Epoch 00061: val_loss did not improve from 0.11073
# Epoch 62/200
# 16508/16508 [==============================] - 4s 218us/step - loss: 0.0622 - acc: 0.9793 - val_loss: 0.1716 - val_acc: 0.9506
#
# Epoch 00062: val_loss did not improve from 0.11073
# Epoch 63/200
# 16508/16508 [==============================] - 4s 217us/step - loss: 0.0713 - acc: 0.9768 - val_loss: 0.1180 - val_acc: 0.9612
#
# Epoch 00063: val_loss did not improve from 0.11073
# Epoch 64/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.0623 - acc: 0.9776 - val_loss: 0.1402 - val_acc: 0.9578
#
# Epoch 00064: val_loss did not improve from 0.11073
# Epoch 65/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.0677 - acc: 0.9770 - val_loss: 0.1191 - val_acc: 0.9598
#
# Epoch 00065: val_loss did not improve from 0.11073
# Epoch 66/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0609 - acc: 0.9775 - val_loss: 0.1264 - val_acc: 0.9612
#
# Epoch 00066: val_loss did not improve from 0.11073
# Epoch 67/200
# 16508/16508 [==============================] - 3s 210us/step - loss: 0.0579 - acc: 0.9810 - val_loss: 0.1447 - val_acc: 0.9549
#
# Epoch 00067: val_loss did not improve from 0.11073
# Epoch 68/200
# 16508/16508 [==============================] - 4s 212us/step - loss: 0.0573 - acc: 0.9815 - val_loss: 0.1141 - val_acc: 0.9656
#
# Epoch 00068: val_loss did not improve from 0.11073
# Epoch 69/200
# 16508/16508 [==============================] - 3s 210us/step - loss: 0.0581 - acc: 0.9795 - val_loss: 0.1213 - val_acc: 0.9608
#
# Epoch 00069: val_loss did not improve from 0.11073
# Epoch 70/200
# 16508/16508 [==============================] - 3s 210us/step - loss: 0.0566 - acc: 0.9806 - val_loss: 0.1194 - val_acc: 0.9588
#
# Epoch 00070: val_loss did not improve from 0.11073
# Epoch 71/200
# 16508/16508 [==============================] - 3s 212us/step - loss: 0.0553 - acc: 0.9823 - val_loss: 0.1247 - val_acc: 0.9617
#
# Epoch 00071: val_loss did not improve from 0.11073
# Epoch 72/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0667 - acc: 0.9776 - val_loss: 0.1111 - val_acc: 0.9675
#
# Epoch 00072: val_loss did not improve from 0.11073
# Epoch 73/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0542 - acc: 0.9826 - val_loss: 0.1158 - val_acc: 0.9656
#
# Epoch 00073: val_loss did not improve from 0.11073
# Epoch 74/200
# 16508/16508 [==============================] - 4s 213us/step - loss: 0.0616 - acc: 0.9787 - val_loss: 0.1375 - val_acc: 0.9578
#
# Epoch 00074: val_loss did not improve from 0.11073
# Epoch 75/200
# 16508/16508 [==============================] - 3s 206us/step - loss: 0.0541 - acc: 0.9809 - val_loss: 0.1355 - val_acc: 0.9564
#
# Epoch 00075: val_loss did not improve from 0.11073
# Epoch 76/200
# 16508/16508 [==============================] - 3s 206us/step - loss: 0.0529 - acc: 0.9818 - val_loss: 0.1214 - val_acc: 0.9632
#
# Epoch 00076: val_loss did not improve from 0.11073
# Epoch 77/200
# 16508/16508 [==============================] - 3s 209us/step - loss: 0.0576 - acc: 0.9806 - val_loss: 0.1388 - val_acc: 0.9535
#
# Epoch 00077: val_loss did not improve from 0.11073
# Epoch 78/200
# 16508/16508 [==============================] - 4s 216us/step - loss: 0.0541 - acc: 0.9826 - val_loss: 0.1229 - val_acc: 0.9612
#
# Epoch 00078: val_loss did not improve from 0.11073
# Epoch 79/200
# 16508/16508 [==============================] - 3s 206us/step - loss: 0.0581 - acc: 0.9807 - val_loss: 0.1163 - val_acc: 0.9632
#
# Epoch 00079: val_loss did not improve from 0.11073
# Epoch 80/200
# 16508/16508 [==============================] - 3s 206us/step - loss: 0.0552 - acc: 0.9823 - val_loss: 0.1281 - val_acc: 0.9617
#
# Epoch 00080: val_loss did not improve from 0.11073
# Epoch 81/200
# 16508/16508 [==============================] - 3s 206us/step - loss: 0.0593 - acc: 0.9801 - val_loss: 0.1142 - val_acc: 0.9612
#
# Epoch 00081: val_loss did not improve from 0.11073
# Epoch 82/200
# 16508/16508 [==============================] - 3s 206us/step - loss: 0.0451 - acc: 0.9842 - val_loss: 0.1133 - val_acc: 0.9680
#
# Epoch 00082: val_loss did not improve from 0.11073
# Epoch 83/200
# 16508/16508 [==============================] - 3s 205us/step - loss: 0.0562 - acc: 0.9807 - val_loss: 0.1549 - val_acc: 0.9549
#
# Epoch 00083: val_loss did not improve from 0.11073
# Epoch 84/200
# 16508/16508 [==============================] - 3s 207us/step - loss: 0.0509 - acc: 0.9833 - val_loss: 0.1087 - val_acc: 0.9641
#
# Epoch 00084: val_loss improved from 0.11073 to 0.10868, saving model to disease_selected_100.h5
# Epoch 85/200
# 16508/16508 [==============================] - 4s 212us/step - loss: 0.0458 - acc: 0.9847 - val_loss: 0.1086 - val_acc: 0.9661
#
# Epoch 00085: val_loss improved from 0.10868 to 0.10855, saving model to disease_selected_100.h5
# Epoch 86/200
# 16508/16508 [==============================] - 4s 231us/step - loss: 0.0505 - acc: 0.9830 - val_loss: 0.1307 - val_acc: 0.9617
#
# Epoch 00086: val_loss did not improve from 0.10855
# Epoch 87/200
# 16508/16508 [==============================] - 4s 214us/step - loss: 0.0510 - acc: 0.9826 - val_loss: 0.1285 - val_acc: 0.9593
#
# Epoch 00087: val_loss did not improve from 0.10855
# Epoch 88/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0546 - acc: 0.9825 - val_loss: 0.1366 - val_acc: 0.9603
#
# Epoch 00088: val_loss did not improve from 0.10855
# Epoch 89/200
# 16508/16508 [==============================] - 3s 211us/step - loss: 0.0491 - acc: 0.9836 - val_loss: 0.1106 - val_acc: 0.9651
#
# Epoch 00089: val_loss did not improve from 0.10855
# Epoch 90/200
#  7744/16508 [=============>................] - ETA: 1s - loss: 0.0473 - acc: 0.9840

# %%
model.evaluate(X_test, Y_test)
# Out:
# 2064/2064 [==============================] - 0s 144us/step
# [0.15248625767020177, 0.9597868217054264]
